# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewSmith44/MAT421/blob/main/Module_E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Continuity and Differentiation
#
# Continuity and differentiation are fundamental concepts in calculus. A function is continuous if small changes in the input result in small changes in the output, and differentiable if it has a well-defined derivative.
#
# 1.1 Continuity
#
# A function 𝑓(𝑥) is continuous at a point 𝑥 = 𝑐
# if:
#
# lim ⁡ 𝑥 → 𝑐 𝑓 ( 𝑥 ) = 𝑓(𝑐)
#
# This means that there are no jumps, holes, or asymptotes at 𝑥 = 𝑐 .
#
# Example Code: Checking Continuity

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.where(x < 0, x**2, x + 1)

x_values = np.linspace(-2, 2, 400)
y_values = f(x_values)

plt.plot(x_values, y_values, label=r'$f(x)$', color='blue')
plt.axvline(x=0, color='red', linestyle='--', label="x = 0")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Example of a Continuous Function')
plt.legend()
plt.show()

# %% [markdown]
# 1.2 Differentiation
#
# A function is differentiable at 𝑥 = 𝑐
# if the derivative exists at that point:
#
# 𝑓′(𝑥)=
# lim
# ⁡
# ℎ
# →
# 0
# 𝑓
# (
# 𝑥
# +
# ℎ
# )
# −
# 𝑓
# (
# 𝑥
# )
# ℎ
#
#
# Example Code: Computing Derivatives Using SymPy

# %%
import sympy as sp

x = sp.symbols('x')
f = x**3 + 2*x**2 - 5*x + 1

f_prime = sp.diff(f, x)
f_double_prime = sp.diff(f_prime, x)

print("First derivative:", f_prime)
print("Second derivative:", f_double_prime)
# Out:
# First derivative: 3*x**2 + 4*x - 5
# Second derivative: 6*x + 4

# %% [markdown]
# 2. Taylor's Theorem
#
# Taylor's Theorem approximates a function
# 𝑓
# (
# 𝑥
# )
#  near a point
# 𝑎
# a using a polynomial:
#
# f(x)≈f(a)+f
# ′
#  (a)(x−a)+
# 2!
# f
# ′′
#  (a)
# ​
#  (x−a)
# 2
#  +⋯+
# n!
# f
# (n)
#  (a)
# ​
#  (x−a)
# n
#
#
# 2.1 Taylor Series Approximation
#
# Example Code: Taylor Expansion Using SymPy

# %%
a = 0
taylor_series = f.series(x, a, 4)

print("Taylor Series Expansion at x = 0:", taylor_series)
# Out:
# Taylor Series Expansion at x = 0: x**3 + 2*x**2 - 5*x + 1

# %% [markdown]
# Example Code: Visualizing Taylor Approximation

# %%
f_func = sp.lambdify(x, f, 'numpy')

x_values = np.linspace(-2, 2, 400)
y_values = f_func(x_values)

taylor_func = sp.lambdify(x, taylor_series.removeO(), 'numpy')
taylor_values = taylor_func(x_values)

plt.plot(x_values, y_values, label=r'$f(x)$', color='blue')
plt.plot(x_values, taylor_values, label='Taylor Approximation', linestyle='dashed', color='orange')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Taylor Series Approximation')
plt.legend()
plt.show()

# %% [markdown]
# 3. Optimization with Gradient Descent
#
# Gradient Descent is an iterative optimization algorithm used to find local minima of a function. The update rule is:
#
# 𝑥 𝑛 + 1 =𝑥 𝑛 − 𝛼 ∇ 𝑓(𝑥𝑛)
#
# where
# 𝛼
# α is the learning rate, and
# ∇
# 𝑓
# (
# 𝑥
# 𝑛
# )
#  is the gradient.
#
# 3.1 Implementing Gradient Descent
#
# Example Code: Gradient Descent on a Quadratic Function

# %%
def f(x):
    return x**2 + 2*x + 1

def gradient(x):
    return 2*x + 2

learning_rate = 0.1
x_current = 5
iterations = 20

x_history = [x_current]
for _ in range(iterations):
    x_current = x_current - learning_rate * gradient(x_current)
    x_history.append(x_current)

x_values = np.linspace(-6, 4, 400)
y_values = f(x_values)

plt.plot(x_values, y_values, label=r'$f(x) = x^2 + 2x + 1$', color='blue')
plt.scatter(x_history, [f(x) for x in x_history], color='red', label='Gradient Descent Steps')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gradient Descent Optimization')
plt.legend()
plt.show()

# %% [markdown]
# 4. Conclusion
#
# This assignment covered:
#
# Continuity and differentiation, including computing derivatives using SymPy.
#
# Taylor’s Theorem, with an implementation of Taylor series expansion.
#
# Optimization using Gradient Descent, demonstrating iterative minimization.
#
# This knowledge is crucial in numerical computing, machine learning, and optimization problems.
